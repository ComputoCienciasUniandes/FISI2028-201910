# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('Cars93.csv')

# %%
data[:10]
# Out:
#    Unnamed: 0 Manufacturer       Model     Type  Min.Price  Price  Max.Price  \
# 0           1        Acura     Integra    Small       12.9   15.9       18.8
# 1           2        Acura      Legend  Midsize       29.2   33.9       38.7
# 2           3         Audi          90  Compact       25.9   29.1       32.3
# 3           4         Audi         100  Midsize       30.8   37.7       44.6
# 4           5          BMW        535i  Midsize       23.7   30.0       36.2
# 5           6        Buick     Century  Midsize       14.2   15.7       17.3
# 6           7        Buick     LeSabre    Large       19.9   20.8       21.7
# 7           8        Buick  Roadmaster    Large       22.6   23.7       24.9
# 8           9        Buick     Riviera  Midsize       26.3   26.3       26.3
# 9          10     Cadillac     DeVille    Large       33.0   34.7       36.3
#
#    MPG.city  MPG.highway             AirBags        ...        Passengers  \
# 0        25           31                None        ...                 5
# 1        18           25  Driver & Passenger        ...                 5
# 2        20           26         Driver only        ...                 5
# 3        19           26  Driver & Passenger        ...                 6
# 4        22           30         Driver only        ...                 4
# 5        22           31         Driver only        ...                 6
# 6        19           28         Driver only        ...                 6
# 7        16           25         Driver only        ...                 6
# 8        19           27         Driver only        ...                 5
# 9        16           25         Driver only        ...                 6
#
#   Length  Wheelbase  Width  Turn.circle  Rear.seat.room Luggage.room  Weight  \
# 0    177        102     68           37            26.5         11.0    2705
# 1    195        115     71           38            30.0         15.0    3560
# 2    180        102     67           37            28.0         14.0    3375
# 3    193        106     70           37            31.0         17.0    3405
# 4    186        109     69           39            27.0         13.0    3640
# 5    189        105     69           41            28.0         16.0    2880
# 6    200        111     74           42            30.5         17.0    3470
# 7    216        116     78           45            30.5         21.0    4105
# 8    198        108     73           41            26.5         14.0    3495
# 9    206        114     73           43            35.0         18.0    3620
#
#     Origin              Make
# 0  non-USA     Acura Integra
# 1  non-USA      Acura Legend
# 2  non-USA           Audi 90
# 3  non-USA          Audi 100
# 4  non-USA          BMW 535i
# 5      USA     Buick Century
# 6      USA     Buick LeSabre
# 7      USA  Buick Roadmaster
# 8      USA     Buick Riviera
# 9      USA  Cadillac DeVille
#
# [10 rows x 28 columns]

# %%
data_selecta = data[['Price', 'MPG.city', 'EngineSize', 'Horsepower', 'RPM', 
                     'Fuel.tank.capacity', 'Length', 'Width', 'Turn.circle', 'Weight']]

# %%
data_selecta[:10]
# Out:
#    Price  MPG.city  EngineSize  Horsepower   RPM  Fuel.tank.capacity  Length  \
# 0   15.9        25         1.8         140  6300                13.2     177
# 1   33.9        18         3.2         200  5500                18.0     195
# 2   29.1        20         2.8         172  5500                16.9     180
# 3   37.7        19         2.8         172  5500                21.1     193
# 4   30.0        22         3.5         208  5700                21.1     186
# 5   15.7        22         2.2         110  5200                16.4     189
# 6   20.8        19         3.8         170  4800                18.0     200
# 7   23.7        16         5.7         180  4000                23.0     216
# 8   26.3        19         3.8         170  4800                18.8     198
# 9   34.7        16         4.9         200  4100                18.0     206
#
#    Width  Turn.circle  Weight
# 0     68           37    2705
# 1     71           38    3560
# 2     67           37    3375
# 3     70           37    3405
# 4     69           39    3640
# 5     69           41    2880
# 6     74           42    3470
# 7     78           45    4105
# 8     73           41    3495
# 9     73           43    3620

# %%
_ = pd.plotting.scatter_matrix(data_selecta, figsize=(10,10))
